# %%
from typing import List, Optional
import random
import time
import os

import requests
import ipyplot

# Path to Nebius API key, see instruction on how to get one: https://docs.nebius.com/studio/api/authentication
# Alternatively you can just put it in the notebook for running samples easier:
# TOKEN = *You Nebius API key*
with open(os.path.expanduser("~/.secrets/nebius-openai-api-key")) as f:
  TOKEN = f.read().strip()

def gen_image(model: str, loras: Optional[List[dict]], prompt: str, width: int, height: int, num_inference_steps: int):
  resp = requests.post(
    url="https://api.studio.nebius.com/v1/images/generations",
    headers={"Authorization": f"Bearer {TOKEN}"},
    json={
      "model": model,
      # NEW optional (backward compatible) field
      # [{url, scale}, ...]
      "loras": loras,
      "prompt": prompt,
      "width": width,
      "height": height,
      "num_inference_steps": num_inference_steps,
    },
  )
  if resp.status_code != 200:
    print(resp.text)
    resp.raise_for_status()

  image_url = resp.json()['data'][0]['url']
  content = None
  for i in range(3):
    resp = requests.get(image_url)
    if resp.status_code == 200:
      content = resp.content
      break
    if resp.status_code != 200:
      # BUG: returns 404
      print("No photo:", resp.text)
      time.sleep(1)
      continue
      # resp.raise_for_status()

  if content is None:
    resp.raise_for_status()

  os.makedirs("images", exist_ok=True)
  name = f"images/{''.join([random.choice('abcde') for _ in range(10)])}.webp"
  with open(name, "wb") as f:
    f.write(content)
  return name

def show_3_pics(**kwargs):
  measure = kwargs.get('measure', False)
  if 'measure' in kwargs:
    del kwargs['measure']

  images_list = []
  for _ in range(3):
    before = time.time()
    images_list.append(gen_image(**kwargs))
    if measure:
      print(f"Image generated in {round(time.time() - before)}sec")
  ipyplot.plot_images(images_list, max_images=3, img_width=256)

# %% [markdown]
# # No LoRA

# %%
show_3_pics(
    model="black-forest-labs/flux-dev",
    loras=None,
    prompt="A fancy cat in sunglasses, Studio Ghibli Dark Fairytale, ArsMJStyle, impressionism",
    width=256,
    height=256,
    num_inference_steps=26,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-fToWRyRFh3YQh5B8u3N8xi {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fToWRyRFh3YQh5B8u3N8xi {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fToWRyRFh3YQh5B8u3N8xi {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fToWRyRFh3YQh5B8u3N8xi:checked ~ #ipyplot-html-viewer-textarea-fToWRyRFh3YQh5B8u3N8xi {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fToWRyRFh3YQh5B8u3N8xi:checked + #ipyplot-html-viewer-label-fToWRyRFh3YQh5B8u3N8xi:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-fToWRyRFh3YQh5B8u3N8xi">
#         <label id="ipyplot-html-viewer-label-fToWRyRFh3YQh5B8u3N8xi" for="ipyplot-html-viewer-toggle-fToWRyRFh3YQh5B8u3N8xi">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-fToWRyRFh3YQh5B8u3N8xi" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-WFuxJumEZM42nyRsqADgX5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WFuxJumEZM42nyRsqADgX5 {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WFuxJumEZM42nyRsqADgX5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WFuxJumEZM42nyRsqADgX5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WFuxJumEZM42nyRsqADgX5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WFuxJumEZM42nyRsqADgX5">
#     <div class="ipyplot-placeholder-div-WFuxJumEZM42nyRsqADgX5">
#         <div id="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-3NKUFh6mAiPqvF4YuFYyfR" class="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bbbeecbbcd.webp</h4><img src="images/bbbeecbbcd.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-3NKUFh6mAiPqvF4YuFYyfR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WFuxJumEZM42nyRsqADgX5">
#         <div id="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-4m63RK4ykEnM5EDTjdaGTX" class="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/eccdaacddc.webp</h4><img src="images/eccdaacddc.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-4m63RK4ykEnM5EDTjdaGTX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WFuxJumEZM42nyRsqADgX5">
#         <div id="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-GLMpW2FHWC2wJxLsQvu3yY" class="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ddceaebbbe.webp</h4><img src="images/ddceaebbbe.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-GLMpW2FHWC2wJxLsQvu3yY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-WFuxJumEZM42nyRsqADgX5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WFuxJumEZM42nyRsqADgX5 {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WFuxJumEZM42nyRsqADgX5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WFuxJumEZM42nyRsqADgX5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WFuxJumEZM42nyRsqADgX5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WFuxJumEZM42nyRsqADgX5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WFuxJumEZM42nyRsqADgX5">
#     <div class="ipyplot-placeholder-div-WFuxJumEZM42nyRsqADgX5">
#         <div id="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-3NKUFh6mAiPqvF4YuFYyfR" class="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bbbeecbbcd.webp</h4><img src="images/bbbeecbbcd.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-3NKUFh6mAiPqvF4YuFYyfR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WFuxJumEZM42nyRsqADgX5">
#         <div id="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-4m63RK4ykEnM5EDTjdaGTX" class="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/eccdaacddc.webp</h4><img src="images/eccdaacddc.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-4m63RK4ykEnM5EDTjdaGTX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WFuxJumEZM42nyRsqADgX5">
#         <div id="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-GLMpW2FHWC2wJxLsQvu3yY" class="ipyplot-content-div-WFuxJumEZM42nyRsqADgX5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ddceaebbbe.webp</h4><img src="images/ddceaebbbe.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WFuxJumEZM42nyRsqADgX5-GLMpW2FHWC2wJxLsQvu3yY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# # Let's add 1 LoRA

# %% [markdown]
# ## Dark Ghibli LoRA

# %%
show_3_pics(
    model="black-forest-labs/flux-dev",
    loras=[
      {"url": "https://civitai.com/api/download/models/1524423?type=Model&format=SafeTensor", "scale": 1},
    ],
    prompt="A fancy cat in sunglasses, Studio Ghibli Dark Fairytale, ArsMJStyle, impressionism",
    width=256,
    height=256,
    num_inference_steps=26,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jGCPStSePQKtrpDQAPo9pP {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jGCPStSePQKtrpDQAPo9pP {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jGCPStSePQKtrpDQAPo9pP {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jGCPStSePQKtrpDQAPo9pP:checked ~ #ipyplot-html-viewer-textarea-jGCPStSePQKtrpDQAPo9pP {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jGCPStSePQKtrpDQAPo9pP:checked + #ipyplot-html-viewer-label-jGCPStSePQKtrpDQAPo9pP:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jGCPStSePQKtrpDQAPo9pP">
#         <label id="ipyplot-html-viewer-label-jGCPStSePQKtrpDQAPo9pP" for="ipyplot-html-viewer-toggle-jGCPStSePQKtrpDQAPo9pP">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jGCPStSePQKtrpDQAPo9pP" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-HpMFwJPWMVZi8TNt9f9uzy {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HpMFwJPWMVZi8TNt9f9uzy {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-HpMFwJPWMVZi8TNt9f9uzy">
#     <div class="ipyplot-placeholder-div-HpMFwJPWMVZi8TNt9f9uzy">
#         <div id="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-HECNYsQdPpmNSLor5G4Kz9" class="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bedddcebcd.webp</h4><img src="images/bedddcebcd.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-HECNYsQdPpmNSLor5G4Kz9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HpMFwJPWMVZi8TNt9f9uzy">
#         <div id="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-irG3wrVcE48sLQwKD7XPti" class="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/eadbecddcb.webp</h4><img src="images/eadbecddcb.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-irG3wrVcE48sLQwKD7XPti">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HpMFwJPWMVZi8TNt9f9uzy">
#         <div id="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-6aRqfB4FVAVYpWmM9aUEjZ" class="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/baaabaaded.webp</h4><img src="images/baaabaaded.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-6aRqfB4FVAVYpWmM9aUEjZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-HpMFwJPWMVZi8TNt9f9uzy {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HpMFwJPWMVZi8TNt9f9uzy {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-HpMFwJPWMVZi8TNt9f9uzy">
#     <div class="ipyplot-placeholder-div-HpMFwJPWMVZi8TNt9f9uzy">
#         <div id="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-HECNYsQdPpmNSLor5G4Kz9" class="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bedddcebcd.webp</h4><img src="images/bedddcebcd.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-HECNYsQdPpmNSLor5G4Kz9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HpMFwJPWMVZi8TNt9f9uzy">
#         <div id="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-irG3wrVcE48sLQwKD7XPti" class="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/eadbecddcb.webp</h4><img src="images/eadbecddcb.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-irG3wrVcE48sLQwKD7XPti">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HpMFwJPWMVZi8TNt9f9uzy">
#         <div id="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-6aRqfB4FVAVYpWmM9aUEjZ" class="ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/baaabaaded.webp</h4><img src="images/baaabaaded.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HpMFwJPWMVZi8TNt9f9uzy-6aRqfB4FVAVYpWmM9aUEjZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## Impressionism LoRA

# %%
show_3_pics(
    model="black-forest-labs/flux-dev",
    loras=[
      {"url": "https://civitai.com/api/download/models/755598?type=Model&format=SafeTensor", "scale": 0.8},
    ],
    prompt="A fancy cat in sunglasses, Studio Ghibli Dark Fairytale, ArsMJStyle, impressionism",
    width=256,
    height=256,
    num_inference_steps=26,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Bwzoz4osueeyqTScx6utYJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Bwzoz4osueeyqTScx6utYJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Bwzoz4osueeyqTScx6utYJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Bwzoz4osueeyqTScx6utYJ:checked ~ #ipyplot-html-viewer-textarea-Bwzoz4osueeyqTScx6utYJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Bwzoz4osueeyqTScx6utYJ:checked + #ipyplot-html-viewer-label-Bwzoz4osueeyqTScx6utYJ:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Bwzoz4osueeyqTScx6utYJ">
#         <label id="ipyplot-html-viewer-label-Bwzoz4osueeyqTScx6utYJ" for="ipyplot-html-viewer-toggle-Bwzoz4osueeyqTScx6utYJ">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Bwzoz4osueeyqTScx6utYJ" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-R4yvgzm7bsgbre9rHXnLtJ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-R4yvgzm7bsgbre9rHXnLtJ {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-R4yvgzm7bsgbre9rHXnLtJ">
#     <div class="ipyplot-placeholder-div-R4yvgzm7bsgbre9rHXnLtJ">
#         <div id="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-Q5qNDNCva2LFfBXFVM5KLy" class="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/adbebecbdd.webp</h4><img src="images/adbebecbdd.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-Q5qNDNCva2LFfBXFVM5KLy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-R4yvgzm7bsgbre9rHXnLtJ">
#         <div id="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-nrWsTWT4DvNvG7CtLW5xJP" class="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/eaecaaecde.webp</h4><img src="images/eaecaaecde.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-nrWsTWT4DvNvG7CtLW5xJP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-R4yvgzm7bsgbre9rHXnLtJ">
#         <div id="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-dWWFFPcPexJsN6UwXJrMEE" class="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/cbbcadddce.webp</h4><img src="images/cbbcadddce.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-dWWFFPcPexJsN6UwXJrMEE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-R4yvgzm7bsgbre9rHXnLtJ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-R4yvgzm7bsgbre9rHXnLtJ {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-R4yvgzm7bsgbre9rHXnLtJ">
#     <div class="ipyplot-placeholder-div-R4yvgzm7bsgbre9rHXnLtJ">
#         <div id="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-Q5qNDNCva2LFfBXFVM5KLy" class="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/adbebecbdd.webp</h4><img src="images/adbebecbdd.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-Q5qNDNCva2LFfBXFVM5KLy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-R4yvgzm7bsgbre9rHXnLtJ">
#         <div id="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-nrWsTWT4DvNvG7CtLW5xJP" class="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/eaecaaecde.webp</h4><img src="images/eaecaaecde.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-nrWsTWT4DvNvG7CtLW5xJP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-R4yvgzm7bsgbre9rHXnLtJ">
#         <div id="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-dWWFFPcPexJsN6UwXJrMEE" class="ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/cbbcadddce.webp</h4><img src="images/cbbcadddce.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-R4yvgzm7bsgbre9rHXnLtJ-dWWFFPcPexJsN6UwXJrMEE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# # Let's use both

# %%
show_3_pics(
    model="black-forest-labs/flux-dev",
    loras=[
      {"url": "https://civitai.com/api/download/models/1524423?type=Model&format=SafeTensor", "scale": 0.7},
      {"url": "https://civitai.com/api/download/models/755598?type=Model&format=SafeTensor", "scale": 0.7},
    ],
    prompt="A fancy cat in sunglasses, Studio Ghibli Dark Fairytale, ArsMJStyle, impressionism",
    width=256,
    height=256,
    num_inference_steps=26,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-UEeBgUT4PbwGmmB2eyvbHj {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UEeBgUT4PbwGmmB2eyvbHj {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UEeBgUT4PbwGmmB2eyvbHj {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UEeBgUT4PbwGmmB2eyvbHj:checked ~ #ipyplot-html-viewer-textarea-UEeBgUT4PbwGmmB2eyvbHj {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UEeBgUT4PbwGmmB2eyvbHj:checked + #ipyplot-html-viewer-label-UEeBgUT4PbwGmmB2eyvbHj:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-UEeBgUT4PbwGmmB2eyvbHj">
#         <label id="ipyplot-html-viewer-label-UEeBgUT4PbwGmmB2eyvbHj" for="ipyplot-html-viewer-toggle-UEeBgUT4PbwGmmB2eyvbHj">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-UEeBgUT4PbwGmmB2eyvbHj" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-g7ab3ou2HEAZjCWBsmzk7z {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-g7ab3ou2HEAZjCWBsmzk7z {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-g7ab3ou2HEAZjCWBsmzk7z">
#     <div class="ipyplot-placeholder-div-g7ab3ou2HEAZjCWBsmzk7z">
#         <div id="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-ZRmuTTvXBuEXq2uFL9eirB" class="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/baeecdabaa.webp</h4><img src="images/baeecdabaa.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-ZRmuTTvXBuEXq2uFL9eirB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-g7ab3ou2HEAZjCWBsmzk7z">
#         <div id="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-kxLvL86M4ywePanvsgb8BW" class="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/aeedaceede.webp</h4><img src="images/aeedaceede.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-kxLvL86M4ywePanvsgb8BW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-g7ab3ou2HEAZjCWBsmzk7z">
#         <div id="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-h9ZiGpvWFRhDKRZvFWAwCJ" class="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/beeadadead.webp</h4><img src="images/beeadadead.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-h9ZiGpvWFRhDKRZvFWAwCJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-g7ab3ou2HEAZjCWBsmzk7z {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-g7ab3ou2HEAZjCWBsmzk7z {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-g7ab3ou2HEAZjCWBsmzk7z">
#     <div class="ipyplot-placeholder-div-g7ab3ou2HEAZjCWBsmzk7z">
#         <div id="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-ZRmuTTvXBuEXq2uFL9eirB" class="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/baeecdabaa.webp</h4><img src="images/baeecdabaa.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-ZRmuTTvXBuEXq2uFL9eirB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-g7ab3ou2HEAZjCWBsmzk7z">
#         <div id="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-kxLvL86M4ywePanvsgb8BW" class="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/aeedaceede.webp</h4><img src="images/aeedaceede.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-kxLvL86M4ywePanvsgb8BW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-g7ab3ou2HEAZjCWBsmzk7z">
#         <div id="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-h9ZiGpvWFRhDKRZvFWAwCJ" class="ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/beeadadead.webp</h4><img src="images/beeadadead.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-g7ab3ou2HEAZjCWBsmzk7z-h9ZiGpvWFRhDKRZvFWAwCJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# # Other models & auth

# %% [markdown]
# ## No LoRA

# %%
show_3_pics(
    model="black-forest-labs/flux-schnell",
    loras=None,
    prompt="xuer Asgard City,Diesel punk, diesel punk style,Realistic，Hyper-realistic，motion blur,going really fast masterpiece, deep focus, exaggerated Ghost in the Shell scenes and girl In a sci-fi mechanical chariot, in the style of cyberpunk imagery, in the style of hyper-realistic sci-fi, 32k uhd, marc simonetti, realistic and hyper-detailed renderings, snailcore, artgerm, neo-futuristic grand cybernetwork buildings, patchwork, exquisite details, complex and reasonable structures, bright, daytime, bustling cybercity and streets,full-line projection screens, special effects, laser rain, fluorescence, Asgard City, patchwork,  neon lights, Regular, Special Effects, Holographic Network, Exaggerated Facade, Walker, cinematic photo This is a poster about the Asgard City，It has a realistic picture effect，The picture is messy and extremely rich in details，(The theme text of the poster is: 'XUER':1.2)，One line apart,(the subtitle below reads: 'Asgard City':1.2), golden hour,unconventional supreme masterpiece,masterful details,temperate atmosphere,with a high-end texture,in the style of fashion photography,magazine cover,Dynamic Angle,Dynamic posture,Perspective, unconventional supreme masterpiece,masterful details,see-through,light particles,realistic，Silk, embroidery,Rust,Blue eyes",
    width=256,
    height=256,
    num_inference_steps=16,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-jrK85MJDvENJJM39FJbNBX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jrK85MJDvENJJM39FJbNBX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jrK85MJDvENJJM39FJbNBX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jrK85MJDvENJJM39FJbNBX:checked ~ #ipyplot-html-viewer-textarea-jrK85MJDvENJJM39FJbNBX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jrK85MJDvENJJM39FJbNBX:checked + #ipyplot-html-viewer-label-jrK85MJDvENJJM39FJbNBX:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jrK85MJDvENJJM39FJbNBX">
#         <label id="ipyplot-html-viewer-label-jrK85MJDvENJJM39FJbNBX" for="ipyplot-html-viewer-toggle-jrK85MJDvENJJM39FJbNBX">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jrK85MJDvENJJM39FJbNBX" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-kniJNfNPrv4PrUqyqrKSj9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kniJNfNPrv4PrUqyqrKSj9 {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kniJNfNPrv4PrUqyqrKSj9">
#     <div class="ipyplot-placeholder-div-kniJNfNPrv4PrUqyqrKSj9">
#         <div id="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-oSNJHq79jQhcsgFqqxf2Qq" class="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ebeacbbace.webp</h4><img src="images/ebeacbbace.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-oSNJHq79jQhcsgFqqxf2Qq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kniJNfNPrv4PrUqyqrKSj9">
#         <div id="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-St2mTo2eMSsxxmPoo69Ba3" class="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/aadbadccea.webp</h4><img src="images/aadbadccea.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-St2mTo2eMSsxxmPoo69Ba3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kniJNfNPrv4PrUqyqrKSj9">
#         <div id="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-h6KsVp7us6DiJXq6op5Cwz" class="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/beeddbbeab.webp</h4><img src="images/beeddbbeab.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-h6KsVp7us6DiJXq6op5Cwz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-kniJNfNPrv4PrUqyqrKSj9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kniJNfNPrv4PrUqyqrKSj9 {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kniJNfNPrv4PrUqyqrKSj9">
#     <div class="ipyplot-placeholder-div-kniJNfNPrv4PrUqyqrKSj9">
#         <div id="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-oSNJHq79jQhcsgFqqxf2Qq" class="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ebeacbbace.webp</h4><img src="images/ebeacbbace.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-oSNJHq79jQhcsgFqqxf2Qq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kniJNfNPrv4PrUqyqrKSj9">
#         <div id="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-St2mTo2eMSsxxmPoo69Ba3" class="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/aadbadccea.webp</h4><img src="images/aadbadccea.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-St2mTo2eMSsxxmPoo69Ba3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kniJNfNPrv4PrUqyqrKSj9">
#         <div id="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-h6KsVp7us6DiJXq6op5Cwz" class="ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/beeddbbeab.webp</h4><img src="images/beeddbbeab.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kniJNfNPrv4PrUqyqrKSj9-h6KsVp7us6DiJXq6op5Cwz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## LoRA under authwall
# https://civitai.com/models/329635?modelVersionId=899864

# %%
show_3_pics(
    model="black-forest-labs/flux-schnell",
    loras=[
      {"url": "https://civitai.com/models/329635?modelVersionId=899864", "scale": 1.0},
    ],
    prompt="xuer Asgard City,Diesel punk, diesel punk style,Realistic，Hyper-realistic，motion blur,going really fast masterpiece, deep focus, exaggerated Ghost in the Shell scenes and girl In a sci-fi mechanical chariot, in the style of cyberpunk imagery, in the style of hyper-realistic sci-fi, 32k uhd, marc simonetti, realistic and hyper-detailed renderings, snailcore, artgerm, neo-futuristic grand cybernetwork buildings, patchwork, exquisite details, complex and reasonable structures, bright, daytime, bustling cybercity and streets,full-line projection screens, special effects, laser rain, fluorescence, Asgard City, patchwork,  neon lights, Regular, Special Effects, Holographic Network, Exaggerated Facade, Walker, cinematic photo This is a poster about the Asgard City，It has a realistic picture effect，The picture is messy and extremely rich in details，(The theme text of the poster is: 'XUER':1.2)，One line apart,(the subtitle below reads: 'Asgard City':1.2), golden hour,unconventional supreme masterpiece,masterful details,temperate atmosphere,with a high-end texture,in the style of fashion photography,magazine cover,Dynamic Angle,Dynamic posture,Perspective, unconventional supreme masterpiece,masterful details,see-through,light particles,realistic，Silk, embroidery,Rust,Blue eyes",
    width=256,
    height=256,
    num_inference_steps=16,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-c89Y9ERJWZqsRxsHweCMFb {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-c89Y9ERJWZqsRxsHweCMFb {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-c89Y9ERJWZqsRxsHweCMFb {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-c89Y9ERJWZqsRxsHweCMFb:checked ~ #ipyplot-html-viewer-textarea-c89Y9ERJWZqsRxsHweCMFb {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-c89Y9ERJWZqsRxsHweCMFb:checked + #ipyplot-html-viewer-label-c89Y9ERJWZqsRxsHweCMFb:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-c89Y9ERJWZqsRxsHweCMFb">
#         <label id="ipyplot-html-viewer-label-c89Y9ERJWZqsRxsHweCMFb" for="ipyplot-html-viewer-toggle-c89Y9ERJWZqsRxsHweCMFb">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-c89Y9ERJWZqsRxsHweCMFb" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-nmDvYrN9VG69NznhErMd37 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-nmDvYrN9VG69NznhErMd37 {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-nmDvYrN9VG69NznhErMd37]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-nmDvYrN9VG69NznhErMd37]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-nmDvYrN9VG69NznhErMd37]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-nmDvYrN9VG69NznhErMd37">
#     <div class="ipyplot-placeholder-div-nmDvYrN9VG69NznhErMd37">
#         <div id="ipyplot-content-div-nmDvYrN9VG69NznhErMd37-bCprJgjpbNpT7i4D826wDi" class="ipyplot-content-div-nmDvYrN9VG69NznhErMd37">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bcabeaadec.webp</h4><img src="images/bcabeaadec.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nmDvYrN9VG69NznhErMd37-bCprJgjpbNpT7i4D826wDi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nmDvYrN9VG69NznhErMd37">
#         <div id="ipyplot-content-div-nmDvYrN9VG69NznhErMd37-VWnB2rGT9PBaGECEpJ7NZ8" class="ipyplot-content-div-nmDvYrN9VG69NznhErMd37">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/cadbbadaad.webp</h4><img src="images/cadbbadaad.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nmDvYrN9VG69NznhErMd37-VWnB2rGT9PBaGECEpJ7NZ8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nmDvYrN9VG69NznhErMd37">
#         <div id="ipyplot-content-div-nmDvYrN9VG69NznhErMd37-6Fhhxc9DyiGTmxrvxArrLk" class="ipyplot-content-div-nmDvYrN9VG69NznhErMd37">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ababaabcbb.webp</h4><img src="images/ababaabcbb.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nmDvYrN9VG69NznhErMd37-6Fhhxc9DyiGTmxrvxArrLk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-nmDvYrN9VG69NznhErMd37 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-nmDvYrN9VG69NznhErMd37 {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-nmDvYrN9VG69NznhErMd37 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-nmDvYrN9VG69NznhErMd37]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-nmDvYrN9VG69NznhErMd37]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-nmDvYrN9VG69NznhErMd37]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-nmDvYrN9VG69NznhErMd37">
#     <div class="ipyplot-placeholder-div-nmDvYrN9VG69NznhErMd37">
#         <div id="ipyplot-content-div-nmDvYrN9VG69NznhErMd37-bCprJgjpbNpT7i4D826wDi" class="ipyplot-content-div-nmDvYrN9VG69NznhErMd37">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bcabeaadec.webp</h4><img src="images/bcabeaadec.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nmDvYrN9VG69NznhErMd37-bCprJgjpbNpT7i4D826wDi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nmDvYrN9VG69NznhErMd37">
#         <div id="ipyplot-content-div-nmDvYrN9VG69NznhErMd37-VWnB2rGT9PBaGECEpJ7NZ8" class="ipyplot-content-div-nmDvYrN9VG69NznhErMd37">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/cadbbadaad.webp</h4><img src="images/cadbbadaad.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nmDvYrN9VG69NznhErMd37-VWnB2rGT9PBaGECEpJ7NZ8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nmDvYrN9VG69NznhErMd37">
#         <div id="ipyplot-content-div-nmDvYrN9VG69NznhErMd37-6Fhhxc9DyiGTmxrvxArrLk" class="ipyplot-content-div-nmDvYrN9VG69NznhErMd37">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ababaabcbb.webp</h4><img src="images/ababaabcbb.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nmDvYrN9VG69NznhErMd37-6Fhhxc9DyiGTmxrvxArrLk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# # LoRA validation and SDXL

# %% [markdown]
# Only civitai is allowed by now

# %%
try:
    show_3_pics(
        model="black-forest-labs/flux-dev",
        loras=[
          {"url": "https://civitai.com/api/download/models/1524423?type=Model&format=SafeTensor", "scale": 0.7},
          {"url": "https://example.com/lora.safetensors", "scale": 0.7},
        ],
        prompt="A fancy cat in sunglasses, Studio Ghibli Dark Fairytale, ArsMJStyle, impressionism",
        width=256,
        height=256,
        num_inference_steps=26,
    )
except Exception as e:
    print(e)
# Out:
# {"detail":"LoRA validation error (https://example.com/lora.safetensors): Unexpected URL host: example.com"}
# 400 Client Error: Bad Request for url: https://api.studio.nebius.com/v1/images/generations

# %% [markdown]
# LoRAs can be < 1GiB, I validate it before downloading

# %%
try:
    show_3_pics(
        model="black-forest-labs/flux-dev",
        loras=[
          {"url": "https://civitai.com/api/download/models/1524423?type=Model&format=SafeTensor", "scale": 0.7},
          {"url": "https://civitai.com/models/251417/midjourney-mimic?modelVersionId=283697", "scale": 0.7},
        ],
        prompt="A fancy cat in sunglasses, Studio Ghibli Dark Fairytale, ArsMJStyle, impressionism",
        width=256,
        height=256,
        num_inference_steps=26,
    )
except Exception as e:
    print(e)
# Out:
# {"detail":"LoRA validation error (https://civitai.com/models/251417/midjourney-mimic?modelVersionId=283697): LoRA cannot be larger than 1073741824bytes"}
# 400 Client Error: Bad Request for url: https://api.studio.nebius.com/v1/images/generations

# %% [markdown]
# civitai.green now works, also caching of LoRA works

# %%
show_3_pics(
    model="black-forest-labs/flux-dev",
    loras=[
      {"url": "https://civitai.green/models/1381703/80s-vintage-photography-schnell-flux-lora?modelVersionId=1590102", "scale": 1.0},
    ],
    prompt="Cat in vintage glasses, old film quality, vntg80_photo",
    width=256,
    height=256,
    num_inference_steps=26,
    measure=True,
)
# Out:
# Image generated in 6sec
# Image generated in 5sec
# Image generated in 5sec
#     <style>
#         #ipyplot-html-viewer-toggle-HDMMq3FhUu7dmkSZR4gAcu {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HDMMq3FhUu7dmkSZR4gAcu {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HDMMq3FhUu7dmkSZR4gAcu {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HDMMq3FhUu7dmkSZR4gAcu:checked ~ #ipyplot-html-viewer-textarea-HDMMq3FhUu7dmkSZR4gAcu {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HDMMq3FhUu7dmkSZR4gAcu:checked + #ipyplot-html-viewer-label-HDMMq3FhUu7dmkSZR4gAcu:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-HDMMq3FhUu7dmkSZR4gAcu">
#         <label id="ipyplot-html-viewer-label-HDMMq3FhUu7dmkSZR4gAcu" for="ipyplot-html-viewer-toggle-HDMMq3FhUu7dmkSZR4gAcu">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-HDMMq3FhUu7dmkSZR4gAcu" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-2Jtveg3WHStXpGJKvCThpQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-2Jtveg3WHStXpGJKvCThpQ {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-2Jtveg3WHStXpGJKvCThpQ">
#     <div class="ipyplot-placeholder-div-2Jtveg3WHStXpGJKvCThpQ">
#         <div id="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-e2vabNudeN7yCRcpCVj8NQ" class="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ceaabdcccc.webp</h4><img src="images/ceaabdcccc.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-e2vabNudeN7yCRcpCVj8NQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2Jtveg3WHStXpGJKvCThpQ">
#         <div id="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-kmb3CHJmhJsRWqudc4UHYT" class="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/adcaaaddaa.webp</h4><img src="images/adcaaaddaa.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-kmb3CHJmhJsRWqudc4UHYT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2Jtveg3WHStXpGJKvCThpQ">
#         <div id="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-bdsePCLHKeGcMWaePqYaL2" class="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/acbdcbeaee.webp</h4><img src="images/acbdcbeaee.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-bdsePCLHKeGcMWaePqYaL2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-2Jtveg3WHStXpGJKvCThpQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-2Jtveg3WHStXpGJKvCThpQ {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-2Jtveg3WHStXpGJKvCThpQ">
#     <div class="ipyplot-placeholder-div-2Jtveg3WHStXpGJKvCThpQ">
#         <div id="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-e2vabNudeN7yCRcpCVj8NQ" class="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ceaabdcccc.webp</h4><img src="images/ceaabdcccc.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-e2vabNudeN7yCRcpCVj8NQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2Jtveg3WHStXpGJKvCThpQ">
#         <div id="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-kmb3CHJmhJsRWqudc4UHYT" class="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/adcaaaddaa.webp</h4><img src="images/adcaaaddaa.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-kmb3CHJmhJsRWqudc4UHYT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-2Jtveg3WHStXpGJKvCThpQ">
#         <div id="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-bdsePCLHKeGcMWaePqYaL2" class="ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/acbdcbeaee.webp</h4><img src="images/acbdcbeaee.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-2Jtveg3WHStXpGJKvCThpQ-bdsePCLHKeGcMWaePqYaL2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## You can also use SDXL 1.0

# %% [markdown]
# Without LoRA

# %%
show_3_pics(
    model="stability-ai/sdxl",
    loras=None,
    prompt="a Delorean on synthwave city <lora:pixelbuildings128-v2:1>",
    width=1024,
    height=1024,
    num_inference_steps=64,
    measure=True,
)
# Out:
# Image generated in 8sec
# Image generated in 8sec
# Image generated in 13sec
#     <style>
#         #ipyplot-html-viewer-toggle-PzCWMpA4a7HvuNxwYFiw3M {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PzCWMpA4a7HvuNxwYFiw3M {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PzCWMpA4a7HvuNxwYFiw3M {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PzCWMpA4a7HvuNxwYFiw3M:checked ~ #ipyplot-html-viewer-textarea-PzCWMpA4a7HvuNxwYFiw3M {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PzCWMpA4a7HvuNxwYFiw3M:checked + #ipyplot-html-viewer-label-PzCWMpA4a7HvuNxwYFiw3M:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-PzCWMpA4a7HvuNxwYFiw3M">
#         <label id="ipyplot-html-viewer-label-PzCWMpA4a7HvuNxwYFiw3M" for="ipyplot-html-viewer-toggle-PzCWMpA4a7HvuNxwYFiw3M">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-PzCWMpA4a7HvuNxwYFiw3M" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-5iTPNfG3RMnJoiT5UapBWg {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5iTPNfG3RMnJoiT5UapBWg {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5iTPNfG3RMnJoiT5UapBWg">
#     <div class="ipyplot-placeholder-div-5iTPNfG3RMnJoiT5UapBWg">
#         <div id="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-UUqfo2WsmzhGXpZMEodzhy" class="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/baebedaaad.webp</h4><img src="images/baebedaaad.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-UUqfo2WsmzhGXpZMEodzhy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5iTPNfG3RMnJoiT5UapBWg">
#         <div id="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-DR6w63Qf4kAuki5TVkevt2" class="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ddedeacdac.webp</h4><img src="images/ddedeacdac.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-DR6w63Qf4kAuki5TVkevt2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5iTPNfG3RMnJoiT5UapBWg">
#         <div id="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-kapUSde7rMczaKS39RAkFm" class="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/deddbbadcc.webp</h4><img src="images/deddbbadcc.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-kapUSde7rMczaKS39RAkFm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-5iTPNfG3RMnJoiT5UapBWg {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5iTPNfG3RMnJoiT5UapBWg {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5iTPNfG3RMnJoiT5UapBWg">
#     <div class="ipyplot-placeholder-div-5iTPNfG3RMnJoiT5UapBWg">
#         <div id="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-UUqfo2WsmzhGXpZMEodzhy" class="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/baebedaaad.webp</h4><img src="images/baebedaaad.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-UUqfo2WsmzhGXpZMEodzhy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5iTPNfG3RMnJoiT5UapBWg">
#         <div id="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-DR6w63Qf4kAuki5TVkevt2" class="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/ddedeacdac.webp</h4><img src="images/ddedeacdac.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-DR6w63Qf4kAuki5TVkevt2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5iTPNfG3RMnJoiT5UapBWg">
#         <div id="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-kapUSde7rMczaKS39RAkFm" class="ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/deddbbadcc.webp</h4><img src="images/deddbbadcc.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5iTPNfG3RMnJoiT5UapBWg-kapUSde7rMczaKS39RAkFm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# With LoRA

# %%
show_3_pics(
    model="stability-ai/sdxl",
    loras=[
      {"url": "https://civitai.com/models/120096/pixel-art-xl?modelVersionId=135931", "scale": 1.0},
    ],
    prompt="a Delorean on synthwave city <lora:pixelbuildings128-v2:1>",
    width=1024,
    height=1024,
    num_inference_steps=64,
    measure=True,
)
# Out:
# Image generated in 19sec
# Image generated in 11sec
# Image generated in 11sec
#     <style>
#         #ipyplot-html-viewer-toggle-72JMqWmg8VsGDgUqTRSHAz {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-72JMqWmg8VsGDgUqTRSHAz {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-72JMqWmg8VsGDgUqTRSHAz {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-72JMqWmg8VsGDgUqTRSHAz:checked ~ #ipyplot-html-viewer-textarea-72JMqWmg8VsGDgUqTRSHAz {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-72JMqWmg8VsGDgUqTRSHAz:checked + #ipyplot-html-viewer-label-72JMqWmg8VsGDgUqTRSHAz:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-72JMqWmg8VsGDgUqTRSHAz">
#         <label id="ipyplot-html-viewer-label-72JMqWmg8VsGDgUqTRSHAz" for="ipyplot-html-viewer-toggle-72JMqWmg8VsGDgUqTRSHAz">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-72JMqWmg8VsGDgUqTRSHAz" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-h4kaAsxJafd7ZQYMPVEYfq {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-h4kaAsxJafd7ZQYMPVEYfq {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-h4kaAsxJafd7ZQYMPVEYfq">
#     <div class="ipyplot-placeholder-div-h4kaAsxJafd7ZQYMPVEYfq">
#         <div id="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-RGpkTJBULgUv6TBXTbxggR" class="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/dbaeaeddab.webp</h4><img src="images/dbaeaeddab.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-RGpkTJBULgUv6TBXTbxggR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-h4kaAsxJafd7ZQYMPVEYfq">
#         <div id="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-cyKqKUpBQ9aqoMfZeqrdSu" class="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/cacbaeacec.webp</h4><img src="images/cacbaeacec.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-cyKqKUpBQ9aqoMfZeqrdSu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-h4kaAsxJafd7ZQYMPVEYfq">
#         <div id="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-eGwi2XbTQpyeNu8e5TmV5d" class="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bacbedccdd.webp</h4><img src="images/bacbedccdd.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-eGwi2XbTQpyeNu8e5TmV5d">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-h4kaAsxJafd7ZQYMPVEYfq {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-h4kaAsxJafd7ZQYMPVEYfq {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-h4kaAsxJafd7ZQYMPVEYfq">
#     <div class="ipyplot-placeholder-div-h4kaAsxJafd7ZQYMPVEYfq">
#         <div id="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-RGpkTJBULgUv6TBXTbxggR" class="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/dbaeaeddab.webp</h4><img src="images/dbaeaeddab.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-RGpkTJBULgUv6TBXTbxggR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-h4kaAsxJafd7ZQYMPVEYfq">
#         <div id="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-cyKqKUpBQ9aqoMfZeqrdSu" class="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/cacbaeacec.webp</h4><img src="images/cacbaeacec.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-cyKqKUpBQ9aqoMfZeqrdSu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-h4kaAsxJafd7ZQYMPVEYfq">
#         <div id="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-eGwi2XbTQpyeNu8e5TmV5d" class="ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bacbedccdd.webp</h4><img src="images/bacbedccdd.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-h4kaAsxJafd7ZQYMPVEYfq-eGwi2XbTQpyeNu8e5TmV5d">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# Without LoRA

# %%
show_3_pics(
    model="stability-ai/sdxl",
    loras=None,
    prompt="dwarf warrior, long beard, heavily armored, shield, fantasy, epic, in the snow,  <lora:EpicF4nta5yXL:0.8>",
    width=1024,
    height=1024,
    num_inference_steps=64,
    measure=True,
)
# Out:
# Image generated in 7sec
# Image generated in 7sec
# Image generated in 7sec
#     <style>
#         #ipyplot-html-viewer-toggle-jVQ7U3E9FRQzcj9DXj39Gu {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jVQ7U3E9FRQzcj9DXj39Gu {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jVQ7U3E9FRQzcj9DXj39Gu {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jVQ7U3E9FRQzcj9DXj39Gu:checked ~ #ipyplot-html-viewer-textarea-jVQ7U3E9FRQzcj9DXj39Gu {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jVQ7U3E9FRQzcj9DXj39Gu:checked + #ipyplot-html-viewer-label-jVQ7U3E9FRQzcj9DXj39Gu:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jVQ7U3E9FRQzcj9DXj39Gu">
#         <label id="ipyplot-html-viewer-label-jVQ7U3E9FRQzcj9DXj39Gu" for="ipyplot-html-viewer-toggle-jVQ7U3E9FRQzcj9DXj39Gu">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jVQ7U3E9FRQzcj9DXj39Gu" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-XG9e7vtYxxnk2gWmDxqsiL {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-XG9e7vtYxxnk2gWmDxqsiL {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-XG9e7vtYxxnk2gWmDxqsiL">
#     <div class="ipyplot-placeholder-div-XG9e7vtYxxnk2gWmDxqsiL">
#         <div id="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-kpcJZe2vUTTQnk7sa5Czwg" class="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/aedcceadac.webp</h4><img src="images/aedcceadac.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-kpcJZe2vUTTQnk7sa5Czwg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XG9e7vtYxxnk2gWmDxqsiL">
#         <div id="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-cRB24R39sW9rsgtj57cXq8" class="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/dddacecade.webp</h4><img src="images/dddacecade.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-cRB24R39sW9rsgtj57cXq8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XG9e7vtYxxnk2gWmDxqsiL">
#         <div id="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-bdWKoLUGDmwZsoCkJp5ghU" class="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/cdadacabeb.webp</h4><img src="images/cdadacabeb.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-bdWKoLUGDmwZsoCkJp5ghU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-XG9e7vtYxxnk2gWmDxqsiL {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-XG9e7vtYxxnk2gWmDxqsiL {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-XG9e7vtYxxnk2gWmDxqsiL">
#     <div class="ipyplot-placeholder-div-XG9e7vtYxxnk2gWmDxqsiL">
#         <div id="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-kpcJZe2vUTTQnk7sa5Czwg" class="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/aedcceadac.webp</h4><img src="images/aedcceadac.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-kpcJZe2vUTTQnk7sa5Czwg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XG9e7vtYxxnk2gWmDxqsiL">
#         <div id="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-cRB24R39sW9rsgtj57cXq8" class="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/dddacecade.webp</h4><img src="images/dddacecade.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-cRB24R39sW9rsgtj57cXq8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XG9e7vtYxxnk2gWmDxqsiL">
#         <div id="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-bdWKoLUGDmwZsoCkJp5ghU" class="ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/cdadacabeb.webp</h4><img src="images/cdadacabeb.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XG9e7vtYxxnk2gWmDxqsiL-bdWKoLUGDmwZsoCkJp5ghU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# Some other LoRA

# %%
show_3_pics(
    model="stability-ai/sdxl",
    loras=[
      {"url": "https://civitai.com/models/470073/popyays-epic-fantasy-style-or-pony-and-sdxl?modelVersionId=560995", "scale": 0.8},
    ],
    prompt="dwarf warrior, long beard, heavily armored, shield, fantasy, epic, in the snow,  <lora:EpicF4nta5yXL:0.8>",
    width=1024,
    height=1024,
    num_inference_steps=64,
    measure=True,
)
# Out:
# Image generated in 10sec
# Image generated in 10sec
# Image generated in 10sec
#     <style>
#         #ipyplot-html-viewer-toggle-dk6znFoSybnSRHX39dpRve {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dk6znFoSybnSRHX39dpRve {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dk6znFoSybnSRHX39dpRve {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dk6znFoSybnSRHX39dpRve:checked ~ #ipyplot-html-viewer-textarea-dk6znFoSybnSRHX39dpRve {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dk6znFoSybnSRHX39dpRve:checked + #ipyplot-html-viewer-label-dk6znFoSybnSRHX39dpRve:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-dk6znFoSybnSRHX39dpRve">
#         <label id="ipyplot-html-viewer-label-dk6znFoSybnSRHX39dpRve" for="ipyplot-html-viewer-toggle-dk6znFoSybnSRHX39dpRve">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-dk6znFoSybnSRHX39dpRve" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-ACWWrJNuStw2RLdwm3RBWR {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ACWWrJNuStw2RLdwm3RBWR {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ACWWrJNuStw2RLdwm3RBWR">
#     <div class="ipyplot-placeholder-div-ACWWrJNuStw2RLdwm3RBWR">
#         <div id="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-XR2SpKsgCRnrD2jsqWnf3W" class="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/aacaaedbac.webp</h4><img src="images/aacaaedbac.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-XR2SpKsgCRnrD2jsqWnf3W">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ACWWrJNuStw2RLdwm3RBWR">
#         <div id="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-2Abw5VV43QKkyWfPxfThr9" class="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/dbdcddaada.webp</h4><img src="images/dbdcddaada.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-2Abw5VV43QKkyWfPxfThr9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ACWWrJNuStw2RLdwm3RBWR">
#         <div id="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-ep7ZS5tN6ioTatrDUQmtZp" class="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bddeedebec.webp</h4><img src="images/bddeedebec.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-ep7ZS5tN6ioTatrDUQmtZp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-ACWWrJNuStw2RLdwm3RBWR {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ACWWrJNuStw2RLdwm3RBWR {
#             width: 256px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR {
#             width: 256px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR img {
#             width: 256px;
#         }
#
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ACWWrJNuStw2RLdwm3RBWR">
#     <div class="ipyplot-placeholder-div-ACWWrJNuStw2RLdwm3RBWR">
#         <div id="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-XR2SpKsgCRnrD2jsqWnf3W" class="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/aacaaedbac.webp</h4><img src="images/aacaaedbac.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-XR2SpKsgCRnrD2jsqWnf3W">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ACWWrJNuStw2RLdwm3RBWR">
#         <div id="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-2Abw5VV43QKkyWfPxfThr9" class="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/dbdcddaada.webp</h4><img src="images/dbdcddaada.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-2Abw5VV43QKkyWfPxfThr9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ACWWrJNuStw2RLdwm3RBWR">
#         <div id="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-ep7ZS5tN6ioTatrDUQmtZp" class="ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">images/bddeedebec.webp</h4><img src="images/bddeedebec.webp"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ACWWrJNuStw2RLdwm3RBWR-ep7ZS5tN6ioTatrDUQmtZp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
